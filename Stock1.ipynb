# %%
#Mia Baden May 21
import pandas as pd 
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt 
import graphviz
# %matplotlib inline
#--------------------
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

df = pd.read_csv('NSE-TATAGLOBAL.csv', error_bad_lines = False)#.drop(’Unnamed: 0’, axis=1)
#print(df)
#Open represent the starting
#Close represent final price

#High Low Last represent the maximum minimum and last price
#Toatal Trade Quantity is the number of shares bought or sold in the day

#df['Date'] = pd.to_datetime(df.Date, format = '%Y/%m/%d')
df['Date'] = df.Date
df.index = df.Date

#plot
plt.figure(figsize=(16, 8))
plt.plot(df['Close'], label ='Close Price history')
#'''

# %%
data = df.sort_index(ascending=True, axis = 0)
#create a seperate dataset
new_data = pd.DataFrame(index=range(0, len(df)), columns=['Date','Close'])

for i in range(0, len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

# %%
#create features
